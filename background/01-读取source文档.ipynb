# %% [markdown]
# ## 主要目的： 读取source文档，并生成对应的list

# %%
class BasePoint:
    def __init__(self,id,point):
        self.id=id
        self.point=point

# %% [markdown]
# ### 1 读取文件

# %%
READ_FILE='all_source.txt'

# %%
f=open(READ_FILE)
